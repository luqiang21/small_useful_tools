# %%
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt
from scipy import stats
import tensorflow as tf
import seaborn as sns
from pylab import rcParams
from sklearn.model_selection import train_test_split
from keras.models import Model, load_model
from keras.layers import Input, Dense
from keras.callbacks import ModelCheckpoint, TensorBoard
from keras import regularizers
# %matplotlib inline
sns.set(style='whitegrid', palette='muted', font_scale=1.5)
rcParams['figure.figsize'] = 14, 8
RANDOM_SEED = 42
LABELS = ["Normal", "Fraud"]
# Out:
# Using Theano backend.

# %%
df = pd.read_csv('/Users/LuQiang/Downloads/creditcard.csv')

# %%
# df['Class'] = np.where(df['USER_SEVERITY']>50, 1, 0)
df['Class'] = df['TRANS_FRAUD']
del df['TRANS_FRAUD']
del df['USER_SEVERITY']
df.shape
# Out:
# (253119, 26)

# %%
df.fillna(0.0,inplace=True)
df.isnull().values.any()
# Out:
# False

# %%
count_classes = pd.value_counts(df['Class'], sort = True)
count_classes.plot(kind = 'bar', rot=0)
plt.title("Transaction class distribution")
plt.xticks(range(2), LABELS)
plt.xlabel("Class")
plt.ylabel("Frequency");

# %%
df['CARD_TRAN_HOUROFDAY'] = pd.to_datetime(df['CARD_TRAN_TIMEOFDAY']).dt.hour
print df.columns
frauds = df[df.Class == 1]
normal = df[df.Class == 0]
frauds.shape
# Out:
# Index([u'Unnamed: 0', u'ID', u'AGE', u'CUSTOMER_SINCE', u'ACCT_SINCE',
#        u'YESTERDAY_BALANCE', u'BALANCE_2DAY', u'BALANCE_5DAY', u'CREDIT_SCORE',
#        u'CARD_TRAN_DAYOFWEEK', u'CARD_TRAN_TIMEOFDAY', u'CARD_TRAN_AMOUNT',
#        u'SERVICE', u'ACCT_TYPE', u'ZIP', u'EMPLOYEE', u'CARD_BIN_NAME',
#        u'CARD_MERCHANT', u'CARD_MERCHANT_TYPE', u'CARD_CITY', u'CARD_STATE',
#        u'CARD_COUNTRY', u'CARD_TRAN_TYPE', u'CARD_RESPONSE_CODE',
#        u'CARD_PRESENT', u'Class', u'CARD_TRAN_HOUROFDAY'],
#       dtype='object')
# (2284, 27)

# %%
normal.shape
# Out:
# (250835, 27)

# %%
frauds.CARD_TRAN_AMOUNT.describe()
# Out:
# count    2284.000000
# mean       49.921243
# std        23.008993
# min         0.870000
# 25%        49.000000
# 50%        50.000000
# 75%        50.000000
# max      1000.000000
# Name: CARD_TRAN_AMOUNT, dtype: float64

# %%
normal.CARD_TRAN_AMOUNT.describe()
# Out:
# count    250835.000000
# mean         58.712100
# std         202.753523
# min           0.000000
# 25%           0.000000
# 50%           7.090000
# 75%          60.000000
# max       33029.770000
# Name: CARD_TRAN_AMOUNT, dtype: float64

# %%
f, (ax1, ax2) = plt.subplots(2, 1, sharex=True)
f.suptitle('Amount per transaction by class')

bins = 50

ax1.hist(frauds.CARD_TRAN_AMOUNT, bins = bins)
ax1.set_title('Fraud')

ax2.hist(normal.CARD_TRAN_AMOUNT, bins = bins)
ax2.set_title('Normal')

plt.xlabel('Amount ($)')
plt.ylabel('Number of Transactions')
plt.xlim((0, 12500))
plt.yscale('log')
plt.show()

# %%
f, (ax1, ax2) = plt.subplots(2, 1, sharex=True)
f.suptitle('Time of transaction vs Amount by class')

ax1.scatter(frauds.CARD_TRAN_HOUROFDAY, frauds.CARD_TRAN_AMOUNT)
ax1.set_title('Fraud')

ax2.scatter(normal.CARD_TRAN_HOUROFDAY, normal.CARD_TRAN_AMOUNT)
ax2.set_title('Normal')

plt.xlabel('Time (hour)')
plt.ylabel('Amount')
plt.show()
